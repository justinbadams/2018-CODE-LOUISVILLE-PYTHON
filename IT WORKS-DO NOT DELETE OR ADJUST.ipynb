# %%
# import neceessary libraries
import csv
import sqlite3
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
# create pandas dataframe from website_data.csv file
df = pd.read_csv('website_data.csv', encoding='utf-8', low_memory=False)
df
# Out:
#      order_number           ordered_item_style ordered_item_size  \
# 0              14     LEGGINGS_ONE_SIZE_SOLIDS          ONE SIZE
# 1              15              CLASSIC_X-LARGE           X-LARGE
# 2              15  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 3              15   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 4              15   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 5              16   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 6              17                   ANA_MEDIUM            MEDIUM
# 7              18                  CARLY_SMALL             SMALL
# 8              20                  JULIA_LARGE             LARGE
# 9              20                  JULIA_LARGE             LARGE
# 10             21                CARLY_X-SMALL           X-SMALL
# 11             21                 MAXI_X-SMALL           X-SMALL
# 12             22    LEGGINGS_ONE_SIZE_SNIMALS          ONE SIZE
# 13             23                CARLY_X-LARGE           X-LARGE
# 14             24                   ANA_MEDIUM            MEDIUM
# 15             25                  CARLY_LARGE             LARGE
# 16             25     LEGGINGS_ONE_SIZE_SOLIDS          ONE SIZE
# 17             27                   IRMA_SMALL             SMALL
# 18             27                   IRMA_SMALL             SMALL
# 19             27                   IRMA_SMALL             SMALL
# 20             29                 CARLY_MEDIUM            MEDIUM
# 21             29                  JULIA_LARGE             LARGE
# 22             29     LEGGINGS_ONE_SIZE_HEARTS          ONE SIZE
# 23             30  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 24             30  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 25             30  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 26             30    LEGGINGS_ONE_SIZE_SNIMALS          ONE SIZE
# 27             32   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 28             32   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 29             33                 CARLY_MEDIUM            MEDIUM
# ..            ...                          ...               ...
# 924           556  LEGGINGS_ONE_SIZE_AMERICANA          ONE SIZE
# 925           556     LEGGINGS_ONE_SIZE_DISNEY          ONE SIZE
# 926           557  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 927           558    LEGGINGS_TC_TWO_GEOMETRIC             TCTWO
# 928           558    LEGGINGS_TC_TWO_GEOMETRIC             TCTWO
# 929           559  LEGGINGS_ONE_SIZE_HALLOWEEN          ONE SIZE
# 930           560              CLASSIC_X-LARGE           X-LARGE
# 931           560              CLASSIC_X-LARGE           X-LARGE
# 932           560    LEGGINGS_TC_TWO_GEOMETRIC             TCTWO
# 933           561     LEGGINGS_ONE_SIZE_DISNEY          ONE SIZE
# 934           562  LEGGINGS_TALL_CURVY_SNIMALS        TALL CURVY
# 935           563  LEGGINGS_ONE_SIZE_HALLOWEEN          ONE SIZE
# 936           563  LEGGINGS_ONE_SIZE_HALLOWEEN          ONE SIZE
# 937           563  LEGGINGS_ONE_SIZE_HALLOWEEN          ONE SIZE
# 938           563    LEGGINGS_ONE_SIZE_SNIMALS          ONE SIZE
# 939           563    LEGGINGS_ONE_SIZE_SNIMALS          ONE SIZE
# 940           564                CARLY_X-LARGE           X-LARGE
# 941           564   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 942           564   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 943           564   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
# 944           564  LEGGINGS_TALL_CURVY_SNIMALS        TALL CURVY
# 945           565                 CASSIE_LARGE             LARGE
# 946           566     LEGGINGS_ONE_SIZE_DISNEY          ONE SIZE
# 947           566  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 948           566  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 949           566  LEGGINGS_ONE_SIZE_GEOMETRIC          ONE SIZE
# 950           566                  RANDY_LARGE             LARGE
# 951           567     LEGGINGS_ONE_SIZE_DISNEY          ONE SIZE
# 952           568    LEGGINGS_TC_TWO_GEOMETRIC             TCTWO
# 953           569   LEGGINGS_TALL_CURVY_FLORAL        TALL CURVY
#
#     ordered_item_pattern  total    shipto_person_name shipto_person_city  \
# 0                 SOLIDS     25        Lynsey Herlihy      Arroyo Grande
# 1                    NaN     35         Sarah Shields      Baldwinsville
# 2              GEOMETRIC     25         Sarah Shields      Baldwinsville
# 3                 FLORAL     25         Sarah Shields      Baldwinsville
# 4                 FLORAL     25         Sarah Shields      Baldwinsville
# 5                 FLORAL     25           Dari Norman          Greenwich
# 6                    NaN     48     Cynthia Christner          Vicksburg
# 7                    NaN     55  Mary Helen Cepparulo            Jackson
# 8                    NaN     36         Deborah Adamo            Webster
# 9                    NaN     36         Deborah Adamo            Webster
# 10                   NaN     55     jennifer crawford               troy
# 11                   NaN     42     jennifer crawford               troy
# 12               ANIMALS     25     jennifer crawford               troy
# 13                   NaN     55            Lisa Bauer             Dayton
# 14                   NaN     48  Phyllis Amlin Snyder            Waverly
# 15                   NaN     55         Donna Ratliff          Salisbury
# 16                SOLIDS     23         Donna Ratliff          Salisbury
# 17                   NaN     35      Paulette Latorre          Riverview
# 18                   NaN     35      Paulette Latorre          Riverview
# 19                   NaN     35      Paulette Latorre          Riverview
# 20                   NaN     55         Harriet Klein          Maplewood
# 21                   NaN     36         Harriet Klein          Maplewood
# 22                HEARTS     25         Harriet Klein          Maplewood
# 23             GEOMETRIC     25        Bonnye Luchini          Fairfield
# 24             GEOMETRIC     25        Bonnye Luchini          Fairfield
# 25             GEOMETRIC     25        Bonnye Luchini          Fairfield
# 26               ANIMALS     25        Bonnye Luchini          Fairfield
# 27                FLORAL     25           Kathy Shiel       hudson Falls
# 28                FLORAL     25           Kathy Shiel       hudson Falls
# 29                   NaN     55           Connie Rice         Lost Creek
# ..                   ...    ...                   ...                ...
# 924            AMERICANA     25                  Gail          Bryn Mawr
# 925               DISNEY     25                  Gail          Bryn Mawr
# 926            GEOMETRIC     25      Joyce L. Strauch        San Antonio
# 927            GEOMETRIC     25          Julia Wilson            Phoenix
# 928            GEOMETRIC     25          Julia Wilson            Phoenix
# 929            HALLOWEEN     30        Allison Strait          Baltimore
# 930                  NaN     35         Bonnie Warner     West Bountiful
# 931                  NaN     35         Bonnie Warner     West Bountiful
# 932            GEOMETRIC     25         Bonnie Warner     West Bountiful
# 933               DISNEY     25         HEATHER LEAHY             SELDEN
# 934              ANIMALS     25        Marcella Jones         Birmingham
# 935            HALLOWEEN     30           Cindy Scott        Panama City
# 936            HALLOWEEN     30           Cindy Scott        Panama City
# 937            HALLOWEEN     30           Cindy Scott        Panama City
# 938              ANIMALS     30           Cindy Scott        Panama City
# 939              ANIMALS     30           Cindy Scott        Panama City
# 940                  NaN     55      Lucinda LOCKLEAR          Lumberton
# 941               FLORAL     25      Lucinda LOCKLEAR          Lumberton
# 942               FLORAL     25      Lucinda LOCKLEAR          Lumberton
# 943               FLORAL     25      Lucinda LOCKLEAR          Lumberton
# 944              ANIMALS     25      Lucinda LOCKLEAR          Lumberton
# 945                  NaN     28    Dori Edmonds Jones        Shaker Hts.
# 946               DISNEY     25    Billie Faye Beaver           Weleetka
# 947            GEOMETRIC     25    Billie Faye Beaver           Weleetka
# 948            GEOMETRIC     25    Billie Faye Beaver           Weleetka
# 949            GEOMETRIC     25    Billie Faye Beaver           Weleetka
# 950                  NaN     35    Billie Faye Beaver           Weleetka
# 951               DISNEY     25           Amber Fecik           Branford
# 952            GEOMETRIC     25        Mary Fairfield   Huntington Beach
# 953               FLORAL     25        Mary Fairfield   Huntington Beach
#
#     shipto_person_state_code shipto_person_state_name  \
# 0                         CA               California
# 1                         NY                 New York
# 2                         NY                 New York
# 3                         NY                 New York
# 4                         NY                 New York
# 5                         NY                 New York
# 6                         MI                 Michigan
# 7                         TN                Tennessee
# 8                         NY                 New York
# 9                         NY                 New York
# 10                        MI                 Michigan
# 11                        MI                 Michigan
# 12                        MI                 Michigan
# 13                        OH                     Ohio
# 14                        OH                     Ohio
# 15                        MO                 Missouri
# 16                        MO                 Missouri
# 17                        MI                 Michigan
# 18                        MI                 Michigan
# 19                        MI                 Michigan
# 20                        NJ               New Jersey
# 21                        NJ               New Jersey
# 22                        NJ               New Jersey
# 23                        CA               California
# 24                        CA               California
# 25                        CA               California
# 26                        CA               California
# 27                        NY                 New York
# 28                        NY                 New York
# 29                        WV            West Virginia
# ..                       ...                      ...
# 924                       PA             Pennsylvania
# 925                       PA             Pennsylvania
# 926                       TX                    Texas
# 927                       AZ                  Arizona
# 928                       AZ                  Arizona
# 929                       MD                 Maryland
# 930                       UT                     Utah
# 931                       UT                     Utah
# 932                       UT                     Utah
# 933                       NY                 New York
# 934                       AL                  Alabama
# 935                       FL                  Florida
# 936                       FL                  Florida
# 937                       FL                  Florida
# 938                       FL                  Florida
# 939                       FL                  Florida
# 940                       NC           North Carolina
# 941                       NC           North Carolina
# 942                       NC           North Carolina
# 943                       NC           North Carolina
# 944                       NC           North Carolina
# 945                       OH                     Ohio
# 946                       OK                 Oklahoma
# 947                       OK                 Oklahoma
# 948                       OK                 Oklahoma
# 949                       OK                 Oklahoma
# 950                       OK                 Oklahoma
# 951                       CT              Connecticut
# 952                       CA               California
# 953                       CA               California
#
#     shipto_person_country_code shipto_person_postal_code coupon_code
# 0                           US                     93420         NaN
# 1                           US                     13027         NaN
# 2                           US                     13027         NaN
# 3                           US                     13027         NaN
# 4                           US                     13027         NaN
# 5                           US                     12834   LETSGOROE
# 6                           US                     49097         NaN
# 7                           US                     38305         NaN
# 8                           US                     14580         NaN
# 9                           US                     14580         NaN
# 10                          US                     48083         NaN
# 11                          US                     48083         NaN
# 12                          US                     48083         NaN
# 13                          US                     45415         NaN
# 14                          US                     45690         NaN
# 15                          US                     65281  SPRINGFREE
# 16                          US                     65281         NaN
# 17                          US                     48193         NaN
# 18                          US                     48193         NaN
# 19                          US                     48193         NaN
# 20                          US                      7040         NaN
# 21                          US                      7040         NaN
# 22                          US                      7040         NaN
# 23                          US                     94533         NaN
# 24                          US                     94533         NaN
# 25                          US                     94533         NaN
# 26                          US                     94533         NaN
# 27                          US                     12839         NaN
# 28                          US                     12839         NaN
# 29                          US                     26385         NaN
# ..                         ...                       ...         ...
# 924                         US                     19010         NaN
# 925                         US                     19010         NaN
# 926                         US                     78232         NaN
# 927                         US                     85085         NaN
# 928                         US                     85085         NaN
# 929                         US                     21237         NaN
# 930                         US                     84087         NaN
# 931                         US                     84087         NaN
# 932                         US                     84087         NaN
# 933                         US                     11784         NaN
# 934                         US                     35242         NaN
# 935                         US                     32405         NaN
# 936                         US                     32405         NaN
# 937                         US                     32405         NaN
# 938                         US                     32405         NaN
# 939                         US                     32405         NaN
# 940                         US                     28358         NaN
# 941                         US                     28358         NaN
# 942                         US                     28358         NaN
# 943                         US                     28358         NaN
# 944                         US                     28358         NaN
# 945                         US                     44122   LETSGOROE
# 946                         US                     74880         NaN
# 947                         US                     74880  HEARTS2018
# 948                         US                     74880         NaN
# 949                         US                     74880         NaN
# 950                         US                     74880         NaN
# 951                         US                      6405         NaN
# 952                         US                     92649         NaN
# 953                         US                     92649         NaN
#
# [954 rows x 12 columns]

# %%
# create connection tpo sqlite databases and start new if does not exist
conn = sqlite3.connect('website.db')

# %%
df.to_sql('website_table', conn, if_exists='replace') # create table inside db

# %%
# return data from db, sort, count
df_website = pd.read_sql_query('SELECT ordered_item_style AS Collection, COUNT(*) AS Items_Sold FROM website_table GROUP BY ordered_item_style, ordered_item_pattern ORDER BY Items_Sold DESC', conn)
df_website
# Out:
#                          Collection  Items_Sold
# 0       LEGGINGS_ONE_SIZE_GEOMETRIC         108
# 1     LEGGINGS_TALL_CURVY_GEOMETRIC          94
# 2        LEGGINGS_TALL_CURVY_FLORAL          70
# 3          LEGGINGS_ONE_SIZE_DISNEY          61
# 4          LEGGINGS_ONE_SIZE_FLORAL          60
# 5          LEGGINGS_ONE_SIZE_HEARTS          48
# 6        LEGGINGS_TALL_CURVY_HEARTS          48
# 7       LEGGINGS_ONE_SIZE_AMERICANA          29
# 8          LEGGINGS_ONE_SIZE_SOLIDS          28
# 9        LEGGINGS_TALL_CURVY_SOLIDS          28
# 10      LEGGINGS_TALL_CURVY_SNIMALS          25
# 11         LEGGINGS_TALL_CURVY_XMAS          25
# 12           LEGGINGS_ONE_SIZE_XMAS          23
# 13        LEGGINGS_ONE_SIZE_SNIMALS          21
# 14       LEGGINGS_TALL_CURVY_DISNEY          21
# 15    LEGGINGS_TALL_CURVY_AMERICANA          19
# 16      LEGGINGS_ONE_SIZE_HALLOWEEN          17
# 17    LEGGINGS_TALL_CURVY_HALLOWEEN          17
# 18                  CLASSIC_X-LARGE          14
# 19                      CARLY_SMALL          11
# 20                      IRMA_MEDIUM          11
# 21                       IRMA_LARGE           9
# 22                      CARLY_LARGE           8
# 23        LEGGINGS_TC_TWO_GEOMETRIC           8
# 24                       IRMA_SMALL           7
# 25           LEGGINGS_TC_TWO_DISNEY           7
# 26           LEGGINGS_TC_TWO_FLORAL           7
# 27                     CARLY_MEDIUM           6
# 28                    CARLY_X-LARGE           6
# 29            LEGGINGS_TWEEN_FLORAL           6
# ..                              ...         ...
# 50                       ANA_MEDIUM           2
# 51                       GIGI_LARGE           2
# 52                      GIGI_MEDIUM           2
# 53                     IRMA_X-LARGE           2
# 54                    JULIA_X-LARGE           2
# 55         LEGGINGS _KIDS_ LXL_XMAS           2
# 56  LEGGINGS _KIDS_ SMALL_AMERICANA           2
# 57       LEGGINGS _KIDS_ SMALL_XMAS           2
# 58              LEGGINGS_TWEEN_XMAS           2
# 59                    PERFECT_SMALL           2
# 60                      RANDY_SMALL           2
# 61                    RANDY_X-SMALL           2
# 62                        ANA_SMALL           1
# 63                      AZURE_LARGE           1
# 64                    CASSIE_MEDIUM           1
# 65                  CLASSIC_X-SMALL           1
# 66                     IRMA_X-SMALL           1
# 67      LEGGINGS _KIDS_ LXL-ANIMALS           1
# 68    LEGGINGS _KIDS_ LXL_HALLOWEEN           1
# 69             LEGGINGS_TC_TWO_XMAS           1
# 70                    LINDSAY_SMALL           1
# 71                       MAXI_SMALL           1
# 72                     MAXI_X-LARGE           1
# 73                     MAXI_X-SMALL           1
# 74                     NICOLE_LARGE           1
# 75                     NICOLE_SMALL           1
# 76                  PERFECT_X-LARGE           1
# 77                    RANDY_X-LARGE           1
# 78                      SARAH_LARGE           1
# 79                    SARAH_X-LARGE           1
#
# [80 rows x 2 columns]

# %%
# make bar chart to display data
f, ax = plt.subplots(figsize=(10,20))

# x-axis counts, y-axis is product
sns.barplot(x='Items_Sold', y='Collection', data=df_website, color='m', label='Total Sales by Pattern')

# label the indexes
ax.set_xlabel('Total Sales')
ax.xaxis.set_label_position('top') 
ax.set_ylabel('Item Description by Style_Size_Pattern') 
ax.xaxis.tick_top()
ax.legend(loc='center right')
plt.show()
